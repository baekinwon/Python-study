# %%
#transfermaket에서 축구선수 몸값 데이터 가져오기

# %%
#request 불러오기

import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
#headers에 'user agent' 값 넣기
#구글에서 my user agent 검색해서 가져오기

headers = {'User-Agent' : ''}

#url 주소 가져오기
#첫페이지 정보 가져오기

url = 'https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?page=1'

#request.get()으로 요청하기

r = requests.get(url, headers = headers)

#200이 나오면 연결성공
r.status_code
# Out:
# 200

# %%
#페이지의 정보를 출력
soup = BeautifulSoup(r.text,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <script type="text/javascript">
#     !function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();
# </script>
# <script>
# window._sp_ = {
#     config: {"accountId":1254,"propertyId":7427,"gdpr":{"consentLanguage":"en"},"baseEndpoint":"https://cdn.privacy-mgmt.com"}}
# </script>
# <script async="" src="https://cdn.privacy-mgmt.com/wrapperMessagingWithoutDetection.js"></script>
# <meta charset="utf-8"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon-16x16.png" rel="shortcut icon" sizes="16x16"/>
# <link href="/android-chrome-192x192.png" rel="shortcut icon" sizes="192x192"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=no" name="viewport"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="article" property="og:type"/>
# <meta content="https://tmssl.akamaized.net/images/tm_logo.png" property="og:image"/>
# <meta content="" property="og:description"/>
# <meta content="Most valuable players | Page 1" property="og:title"/>
# <meta content="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?page=1" property="og:url"/>
# <link href="https://www.transfermarkt.de/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="de" rel="alternate">
# <link href="https://www.transfermarkt.de/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="de-LU" rel="alternate">
# <link href="https://www.transfermarkt.at/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="de-AT" rel="alternate"/>
# <link href="https://www.transfermarkt.ch/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="de-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.com.tr/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="tr" rel="alternate"/>
# <link href="https://www.transfermarkt.it/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="it-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.it/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="it" rel="alternate"/>
# <link href="https://www.transfermarkt.pl/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="pl" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="es" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="es-VE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="es-CU" rel="alternate"/>
# <link href="https://www.transfermarkt.nl/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="nl" rel="alternate"/>
# <link href="https://www.transfermarkt.pt/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="pt" rel="alternate"/>
# <link href="https://www.transfermarkt.world/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="ru" rel="alternate"/>
# <link href="https://www.transfermarkt.world/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="world" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="fr-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="fr" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="fr-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="fr-CI" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="fr-LU" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="fr-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.br/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="en-US" rel="alternate"/>
# <link href="https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.co.in/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="en-IN" rel="alternate"/>
# <link href="https://www.transfermarkt.co.za/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="en-ZA" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="x-default" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="en" rel="alternate"/>
# <link href="https://www.transfermarkt.be/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.ar/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.transfermarkt.mx/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.transfermarkt.co/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.transfermarkt.my/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="ms" rel="alternate"/>
# <link href="https://www.transfermarkt.jp/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="ja" rel="alternate"/>
# <link href="https://www.transfermarkt.co.id/spieler-statistik/wertvollstespieler/marktwertetop?page=1" hreflang="id" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?page=2" rel="next"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/menue.css?lm=1655464651" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/styles/tm-main.min.css?lm=1655464544" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main.css?lm=1655464651" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main_desktop.css?lm=1655464651" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/print.css?_sn=1?lm=1655464651" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/chosen.css?lm=1655464651" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/paginator.css?lm=1655464651" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/statistiken.css?lm=1655464651" rel="stylesheet" type="text/css"/>
# <script src="https://tmssl.akamaized.net/js/vendor/jquery.min.js?lm=1655464644" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b7c5571cf8957553f95f6d9069eaed67/jquery.ba-bbq.min.js?lm=1655464653" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/jquery.scrollTo.min.js?lm=1655464653" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/elinkpagermobile.js?lm=1655464653" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main.js?lm=1655464644" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.ajaxaddition.jquery.js?lm=1655464644" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/functions.js?lm=1655464644" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main_desktop.js?lm=1655464644" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.jquery.js?lm=1655464644" type="text/javascript"></script>
# <title>Most valuable players | Page 1 | Transfermarkt</title>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed"/>
# <link as="script" href="//data-84a0f3455d.transfermarkt.com/iomm/latest/manager/base/es6/bundle.js" id="IOMmBundle" rel="preload"/>
# <link as="script" href="//data-84a0f3455d.transfermarkt.com/iomm/latest/bootstrap/loader.js" rel="preload"/>
# <script src="//data-84a0f3455d.transfermarkt.com/iomm/latest/bootstrap/loader.js" type="text/javascript"></script>
# <script type="text/javascript">
#    tmData = {
#        loggedIn : "0",
#        tmTraffic: "0",
#    };
# </script>
# <script>// Set to the same value as the web property used on the site
# 		var gaProperty = 'UA-3816204-13';
#
# 		// Disable tracking if the opt-out cookie exists.
# 		var disableStr = 'ga-disable-' + gaProperty;
# 		if (document.cookie.indexOf(disableStr + '=true') > -1) {
# 			window[disableStr] = true;
# 		}
#
# 		// Opt-out function
# 		function gaOptout() {
# 			document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 			window[disableStr] = true;
# 		}</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3816204-13"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag() { dataLayer.push(arguments); }
#    gtag('set', 'linker', { 'domains': [/^transfermarkt\.(com|de|nl|it|at|ch|es|fr|com\.tr|pt|tv|pl|co\.uk)$/]});
#    gtag('js', new Date());
#    gtag('set',
#   {
#     'custom_map': {
#                     'dimension1': 'loggedIn',
#                     'dimension2': 'tmTraffic'
#                 }
#   });
#         gtag('config', 'UA-3816204-13', {
#                 'anonymize_ip': true,
#                 'transport_type': 'beacon',
#                 'content_group1': 'statistik',
#                 'content_group2': 'global',
#                 'content_group3': 'wertvollstespieler',
#                 'content_group4': '',
#                 'loggedIn': tmData.loggedIn,
#                 'tmTraffic': tmData.tmTraffic
#             });
#    function tmEvent(category, action, label) {
#                 gtag('event',
#                     action,
#                     {
#                         'event_category': category,
#                         'event_label': label
#                     }
#                 );
#             }
#
#             function tmTiming(value, name, event_category, event_label) {
#                 gtag('event', 'timing_complete', {
#                     name,
#                     value,
#                     event_category,
#                     event_label
#                 });
#             }
#
# 	</script> <script src="https://tmssl.akamaized.net//ads/ads.js" type="text/javascript"></script>
# <script type="text/javascript">
#         window.tmGaId = "UA-3816204-13";
#     </script>
# <!--Tisoomi-->
# <script type="text/javascript">
# /* 20011926 */ !function(t,e){function n(t,e){var n=ut(t);if(!n)return n;if(""!=e)for(var i=0;i<e.length;i++){var l=o(e,i);"^"==l&&(n=n.parentNode),"<"==l&&(n=n.previousElementSibling),">"==l&&(n=n.nextElementSibling),"y"==l&&(n=n.firstChild)}return n}function i(t,e){var n=lt(e);return{x:t.clientX-n.left,y:t.clientY-n.top}}function l(t){for(var e=0,n=0;t;)e+=t.offsetLeft+t.clientLeft,n+=t.offsetTop+t.clientTop,t=t.offsetParent;return{x:e,y:n}}function s(t,e){var n=0,i=0,s=l(e);return(t.pageX||t.pageY)&&(n=t.pageX,i=t.pageY),(t.clientX||t.clientY)&&(n=t.clientX+document.body.scrollLeft+document.documentElement.scrollLeft,i=t.clientY+document.body.scrollTop+document.documentElement.scrollTop),n-=s.x,i-=s.y,{x:n,y:i}}function r(t,e){return it(e)?i(t,e):s(t,e)}function d(t,e){t.addEventListener?m(t,"click",e,!0):t.attachEvent&&t.attachEvent("onclick",function(){return e.call(t,window.event)})}function c(e,n){return t[z("c2V0VGltZW91dA==")](e,n)}function a(t){return parseInt(t.toString().split(".")[0],10)}function o(t,e){return t[e]}function w(){return Ut=(Ot*Ut+Pt)%Nt}function u(){return w()/(Nt-1)}function f(){return u()}function p(t,e){return t>e?t:e}function h(){for(var t="",e=65;e<91;e++)t+=v(e);for(var e=97;e<123;e++)t+=v(e);return t}function v(t){return o(" !\"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ["+o("\\\\",0)+"]^_`abcdefghijklmnopqrstuvwxyz{|}~",t-32)}function z(t){var e,n,i,l,s,r,d,c=h()+"0123456789+/=",a="",w=0;for(t=t.replace(/[^A-Za-z0-9\+\/\=]/g,"");w<t.length;)l=c.indexOf(o(t,w++)),s=c.indexOf(o(t,w++)),r=c.indexOf(o(t,w++)),d=c.indexOf(o(t,w++)),e=l<<2|s>>4,n=(15&s)<<4|r>>2,i=(3&r)<<6|d,a+=v(e),64!=r&&(a+=v(n)),64!=d&&(a+=v(i));return a}function R(){try{return navigator.userAgent||navigator.vendor||window.opera}catch(t){return"unknown"}}function m(t,e,n,i){i=i||!1;try{t.addEventListener(e,n,i)}catch(i){t.attachEvent&&t.attachEvent("on"+e,n)}}function g(t){if(!t)return"";for(var e=z("ISIjJCUmJygpKissLS4vOjs8PT4/QFtcXV5ge3x9"),n="",i=0;i<t.length;i++){n+=e.indexOf(t[i])>-1?z("XA==")+t[i]:t[i]}return n}function x(t){if(!t)return"";var e="";return t.id&&t.id.length>0&&(e+="#"+g(t.id)),t.className&&t.className.length>0&&(e+="."+g(t.className).split(" ").filter(function(t){return t&&t.length>0}).join(".")),e}function k(t){Qt[t]=!1}function j(t,e){var n=Ht++;Qt[n]=!0;var i=function(e){return function(){t.call(null),Qt[n]&&c(i,e)}}(e);return c(i,e),n}function y(t){var e=!1;return Object.keys(t).forEach(function(n){e=e||t[n]}),!e}function q(t,e){return t&&(t.consents&&t.consents[e]||t.legitimateInterests&&t.legitimateInterests[e])}function E(e){return!!t.cwsltf06Flags.strictNCNA&&(q(e,2)&&q(e,7)&&q(e,9)&&q(e,10))}function Z(t,e,n){var i=function(){return!!e()&&(n(),!0)};if(!i()){var l=j(function(){i()&&k(l)},250);i()}}function W(t){T(t)}function T(t){if(t.cwslt4e6sdl&&!t.cwsltf5cInjct){t.cwsltf5cInjct=!0,t.cwslt586Pc={},t.cwsltbabOc=[],t.cwslt57eAm={},t.cwsltd38Av={},t.cwslt083Aw={},t.cwslt1f8Rqr={},t.cwsltcd7Rqq=[],t.cwsltd38Avt={},t.cwslt198Ev={};var n=[];if(!t.cwsltf06Flags.welect.eenabled||MPUOQWelect()){if(cwsltf06Flags.pt69dls){var i=cwsltf06Flags.bac28it,l=cwsltf06Flags.mba2bel||10,s=cwsltf06Flags.ig55cBP,r=function(){var t=D("style");t.type="text/css";var n=!1,i=D("style");i.type="text/css";var l=!1;return function(r,d){if(d)if("b"!==r||n){if("r"===r)if(l){var c=i,a=c.sheet;a.insertRule(d,0)}else l=!0,C(i,d),B(e.body,i)}else{if(n=!0,s)for(var o=0;o<s.length;o++)d=d.replace(new RegExp("([;{])"+s[o]+": [^;]+;","g"),"$1");var c="[^:;{",a="!important;";d=d.replace(new RegExp(c+"}]+: [^;]+\\s"+a,"g"),""),C(t,d),e.head.insertBefore(t,e.head.firstChild)}}}();if(i){if(i.length>l){for(var d=0,c=[0],o=[i[0]],w=1;w<l;w++){for(;c.indexOf(d)>-1;)d=a(f()*i.length);c.push(d),o[w]=i[d]}i=o,cwsltf06Flags.bac28it=o}for(var u={},p=0;p<i.length;p++){var h="string"==typeof i[p]?ut(i[p]):i[p];if(h&&h instanceof Node){var v={element:h,coeaaso:{},rc5fccls:Ft(7),coac9tx:""};if(v.coac9tx+="."+v.rc5fccls+"{",!s||s&&-1===s.in ...
# var d=[Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2k4OO7EMku:i|{{KSVwRorYS4tK4wNJHvgQ8jn6u:6qG|2"+t.cwsltd3aRnd+"KOG4k5x{Xh]FLTx6hG8LXL}FoGg]zOFyM3ihr\\iEV94;33y1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2]IiwrGlvTV3HhPn8trP4N{wqpt|PWvU\\|YsjHZiSY7rT2"+t.cwsltd3aRnd+"NH\\wovqpF779R5;LF\\v7RvuZ[||4U}s;oyZkqJY{vSIxFEF1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh27SVmm]Gy}O56gK5Vq4jxfKtLt|u667g;UW<X\\u3xghWQ2"+t.cwsltd3aRnd+"]GQJ78{x7}|o}Oq6PHn\\Zle|fUh<vfEi}ZqZrzrxxIy<]P{1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2Zv7EeeKumkoPEgzYY{Iph}4TfhQllS6Qv8Z|mm3Ig:}72"+t.cwsltd3aRnd+"U]I5pHL{v4zR:P:MYZE6RtHSJlsftj8n84:HXh\\YMq<Nw\\h1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh26Pj\\X7jfW9Z|Ov<]4<f<SI]7ntWVyvoM:wZ43lenLeLF2"+t.cwsltd3aRnd+"HJZJ[G4KyY}IZ7Z3\\3YwMKloSWHR4z7wZpQH<9k5\\]OXUOq1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2yQUmVHY\\9MwLYuuJeq:f;8vSnNSZVLhn3omZmFoSiJS32"+t.cwsltd3aRnd+"I]\\;uwFWjleyvSj;wzHQzQ[3Q6rKof3j;96]uYfZVLnQE9G1jli",-3)],c=[Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2owS<syG\\|e\\IYPWsKuT|jk64zm|OzhQQJwuX;VGjZiMg2"+t.cwsltd3aRnd+"NZKrpTFQ;FjJRpvmo|rgu5:ekY5sxptP]ZsknJ56rLujs571jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh27jxkysV\\pN|}<5qt<rVZu8HR:5y:O[yW;Qy]WX8FzXX32"+t.cwsltd3aRnd+"NXIO<W;SWLHS|yqSNonXHonuXXJrH]:XK[eH{fJenX3;KoS1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2<EFmk<szX8zY9rfwijx4[LmWMW]SPeF[ZqE:[iTrUU:h2"+t.cwsltd3aRnd+"]]Sj}[vEot3i]L5QPowWgNUZnzly{6[WlS;[hu]EhX<5Tm|1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh27[GElpk3NoNPe<ME4mziLf]sypM3][jgRhTr8gXK[i<H2"+t.cwsltd3aRnd+"EU]i<:g8[QF{IMPfXlz6ZlUTi3mkuGX]q:X4hGFNwVXtWnv1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2rLmmnGpimNqyPUFUjuVJVEXFJ:JT[xvfMPn:hqQsmyHH2"+t.cwsltd3aRnd+"MYU]esmSz:hYsqS6LGMi}QousJp{eqpemW]<[}t]3P9gskm1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2sl5Oj:3u<pRtOu3Y8MpRnZjO]]f6SPhK66{n9}9jYW772"+t.cwsltd3aRnd+"YQEJwNj;sNgs3<<ZiV433Fm<Wzzgj|WZ;U6mviMF<HFqphO1jli",-3)],o=d[1*a(6*n.y/this.offsetHeight)+a(1*n.x/this.offsetWidth)],w=c[1*a(6*n.y/this.offsetHeight)+a(1*n.x/this.offsetWidth)];mt(t,o,w,"_blank")}}),B(w,c),dt(o,w),t.cwsltd3214.a[9440]=w,M([{applyAdText:!0}],w,9440),Mt(w,9440,Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2YO34xZZteo\\<]e<8Q57[u}W8qkn8WuL9xg[{X6<;M7Qf2"+t.cwsltd3aRnd+"IUM5NmMSvTFw4yUn}W8}}mNnq:8hwylojkZXKWpo<tzLR[n1jli",-3)),O(9440,n,!0)}}},function(){O(9440,n,!1)})}function u(e,n,l,s){l||pt(Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2:OZR8[ZL|FoY:sfWJ]KGpXXoT47S]GgL]5ysomWG5<Q[2"+t.cwsltd3aRnd+"V]P7|;QXN}kmEQZurqq8YPUWvRiSHJpFXEey{VGZvxHmKmr1jli",-3),function(){if(!l){l=!0;var c=this;if(c.height<2)return void O(9931,n,!1);if(s==t.cwsltd3aRnd){var o=e,w=D("div");i[""+z(Wt(z("V1o8bGRae29bMzRWUGpAQA=="),-3))]=w,wt(w,"DQJNEIEW");var u=c;t.cwslt57eAm[9931]&&(P(t.cwslt57eAm[9931]),t.cwslt57eAm[9931]=!1),d(u,function(e,n){if(!t.cwslt586Pc[9931]){e.preventDefault(),e.stopPropagation();for(var n=r(e,this),i=0;i<t.cwsltbabOc.length;i++){var l=t.cwsltbabOc[i];if(9931==l.p&&n.x>=l.x&&n.x<l.x+l.w&&n.y>=l.y&&n.y<l.y+l.h){if(l.u){var s=l.t.length>0?l.t:"_self";s=0==e.button&&e.ctrlKey?"_blank":s,mt(t,l.u,l.u,s,!0)}return}}var d=[Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2<Z]VU:7xY;WpkwQuY6Hf8|Z|ks\\Ri7J;ULKmRJUugMO{2"+t.cwsltd3aRnd+"ULIIo}LhE;MRMwFhiKLOfkJ754RF6WWGx]fgWgZZPEk;FgG1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2LKoK[i68uJ<:UfSV9w4i}xuZ[FL]IR[qvUkipIlsWZ|o2"+t.cwsltd3aRnd+"QFGeWGhj4vIF\\TWjsLj4mXk;h:7mWqQmU\\FnFfSxPRiGTS|1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2|JrK\\h9gIKo54I59psq584{LS|GqEvMs7SxOVihEJwzs2"+t.cwsltd3aRnd+"S\\EFM|X7RKpYZnnRP}{8:M][Wm<pfISF{[KRXMIZOGfRt;V1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2[8s5fpMhyWY<3[XoT8n;Ip9G9rwurl;ufroz{u<V8f}T2"+t.cwsltd3aRnd+"S[MoWl7Nimuxo[|JMEUqsh74Gkf{4geXItyMpZG3Yy7R]zq1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2\\rj|HgMTinekfj|]V[<xEOi{oul{uzUsu7T3yY9Stzg;2"+t.cwsltd3aRnd+"GJXJwRll:EU5Ojm|X{uJMPF;}gs4W}{n<6gK}3|vE<jkn6k1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2ys|mkUW\\q8zJTuFgI9T;v8kXXzSuyf\\4k4jPzp5 ...
# var d=[Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2i|Kn\\x9sGoHpY[PZ7sp5No}GoQS4kIf8Gg;pKO3meuMK2"+t.cwsltd3aRnd+"EGIZU[YPjntklsUX[KeOYo;]F48JzIxOjweOke:]F8vxL<71jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2]fXwv:EPrhGF{ENY}6tqsWZ3<T:Uz3lQO]N;Yi43YpkR2"+t.cwsltd3aRnd+"\\NT;OQQMH:P;pIXMhxS4uei5k:rUVRvyiLeVu:9GXMS<Mq<1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2Gph5J43LZV35GJGqg:|4[rhXkQ;3Vymjmjmz{8r\\L]W82"+t.cwsltd3aRnd+"KJNMHFTk|lgPiVw7Om}EzFmL<]WZ}5U6hhWG3Okf{7QlE[p1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2FNtplmrWEjg96llr4Vt8JU{<yO9j[jIIhyXRy6L]jUL|2"+t.cwsltd3aRnd+"XRHr5VYvh94qiUF[[W:tfQ[tF{ZL[9f\\}OG7Y8ER9vYN]Op1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2qsnR\\Oxu3G}}k[nQZUojUwp9in5ErG<KV8pt8OjKiv:x2"+t.cwsltd3aRnd+"UKME3hsFfygqXyPEQT{HZKGwQ3|wktiR3FHhkULiZK;N{nn1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2[\\|qN\\nRW|HW;5EM{Gzn{:w5\\k6EO;kZRItyThz<sVpy2"+t.cwsltd3aRnd+"XXG{Iq3;\\HQo\\sX5983FuEtyTTOFt6::gHp}E6ePHWU{ixr1jli",-3)],c=[Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2i\\Yy{{lKZuM|PSS6jvKo|Ofpxj[jg9HUgt4nu7IlFNNJ2"+t.cwsltd3aRnd+"LHT|m}Vztz\\wmzWxhH::r{WEezt7r3SUW<4mGQ}64K4<6ro1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2\\}3L{QqFLmtx4}u|8;z]WEi|lHFnns4tSMp9[UnhIrwL2"+t.cwsltd3aRnd+"TVTr35JKNRoJYw8mLLRXZu[oF:}3ePpw<J{85xGgJxn;K<\\1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2FHE5:typyV]sJ[8QTk48kjx4pjIYIojjNtUYqPUEsHJv2"+t.cwsltd3aRnd+"GFEUGilw}IE:p:Pz9KwzF{fS|Z}ou7Jgk9jouSkKt:R]s[T1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2kP:H4YL|TyW\\xh:Pime<Xeto9L6o56HEs9]|zhqjN|qS2"+t.cwsltd3aRnd+"FITgSy4MWf|NmqK{p;VHuYy:5keX6NFWUnqHRY9[63FsyEN1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2Q<rs{pL|StW7v5ln6Xe<zxsKN5:tf8|{<RSn|gk{6]xJ2"+t.cwsltd3aRnd+"[XXmfLL4nN[FJ[zxo]z:j6FgtiUeZ<UW8fPs;XXrZf4ZMIj1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2ItxefZWe[jly]|nk[<uQMi67ffSWXmRtXp:Uik36R{\\q2"+t.cwsltd3aRnd+"W\\Wf<LjW<{LvponxYNXtrzWFOPyGHM|6\\nh;OuTk7[k{\\u81jli",-3)],o=d[1*a(6*n.y/this.offsetHeight)+a(1*n.x/this.offsetWidth)],w=c[1*a(6*n.y/this.offsetHeight)+a(1*n.x/this.offsetWidth)];mt(t,o,w,"_blank")}}),B(w,c),B(o,w);var f=t.cwsltd3214.a[8695];f&&f.parentNode.removeChild(f),t.cwsltd3214.a[8705]=w,Mt(w,8705,Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2Y<x3pY3Gp<fT\\fzm<sq4RjWXpLQu}H9KT3Spe{IqwNU62"+t.cwsltd3aRnd+"GYY<H|L4vsWp8f8m]oRH5vxUgSMXVMPmTmPgI<]9YOnJx:M1jli",-3)),O(8705,n,!0)}}},function(){O(8705,n,!1)})}function F(e,i,l){var s=n(""+z(Wt(z("TDZRcGdKTHs="),-3)),"");s?i(s,!e,!1,t.cwsltd3aRnd):l(8939,!e,!1)}function G(e,n,l,s){l||pt(Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2qlHz3;|;mP|NFMr6zJJZel:mZ;3HFOUsoqVyg9\\OpI4R2"+t.cwsltd3aRnd+"YG[Z7m55kkrGEz9{vYQNSRjshFXLJH|TGJIlSgLI4LmuRnr1jli",-3),function(){if(!l){l=!0;var c=this;if(c.height<2)return void O(8939,n,!1);if(s==t.cwsltd3aRnd){var o=e,w=D("div");i[""+z(Wt(z("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94W31Id1FUQEA="),-3))]=w,ot(w,"EXfXplT ");var u=c;t.cwslt57eAm[8939]&&(P(t.cwslt57eAm[8939]),t.cwslt57eAm[8939]=!1),d(u,function(e,n){if(!t.cwslt586Pc[8939]){e.preventDefault(),e.stopPropagation();for(var n=r(e,this),i=0;i<t.cwsltbabOc.length;i++){var l=t.cwsltbabOc[i];if(8939==l.p&&n.x>=l.x&&n.x<l.x+l.w&&n.y>=l.y&&n.y<l.y+l.h){if(l.u){var s=l.t.length>0?l.t:"_self";s=0==e.button&&e.ctrlKey?"_blank":s,mt(t,l.u,l.u,s,!0)}return}}var d=[Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh27J5V}Grs5[8KQT3r7vrN5wfIuQZ4joFpgiv:gJQp\\;tG2"+t.cwsltd3aRnd+"UJO[SS\\;V\\QEowT8JmIxpF7|mrgTI48;tO8]OFm3tv3TNqT1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2GwoJOZl7y5sp]N34}ue6GIzq\\Ut7ethXY6T:KN:ps\\sY2"+t.cwsltd3aRnd+"HQNO::]OiUTSUgL5W|W[UZKvL\\uhERpgZ\\Ler{QG}|I;:wr1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2|4VYis<hx5;WXHKsT]3H;s5{lwoMVY4;74[\\MQoZl|PK2"+t.cwsltd3aRnd+"VRYijh6\\ZK3FOqPzEKfYuF|GzZRvvJ}}J:VHfL{U7m8hTM]1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2SNoSlTuwe[Jvv9RXP{IH[njs3SERQ7LRE<RNjkiIhZrG2"+t.cwsltd3aRnd+"PRX:8xZRX;|VtQRkv5WO{nLjZ;Z\\J3l:MJONmygtN:Pzngr1jli",-3),Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2j<SLyNPi7txt8xvju4M<lsPpFrQSy3jkYSx\\4O9nO ...
# e.open("GET",Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2ISQ|KWrvO7kWUew7RL9TNFqvR;]QU8twkU7]ropR7<GW2"+t.cwsltd3aRnd+"[]I:YWZNp8g:hOXwVsT\\vTJh<gRGMQjXgRlpHVmzi4SL<:U1jli",-3),!0),e.setRequestHeader("Content-Type","text/plain"),e.onreadystatechange=function(){if(4===e.readyState&&200===e.status){var n=z(Wt(e.response,-3)),i=JSON.parse(n);JSON.stringify(i);t.cwsltd321o2=i.css,t.cwsltd321o3=i.generic,t.cwsltd321o3a=i.altGeneric,t.cwsltd321o1=i.url,t.cwsltd321o1a=i.altUrl,J()}},e.send()}else Et(this),J()};t.cwsltccfMobile?pt(Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2LR4nM:]5iH7[P|}8y[r4KJ8:FEy9v4zLoVQXtgTEow[y2"+t.cwsltd3aRnd+"RMEwoNPphHVw:P84fjgQ<}9y4H8ytUNvL:}FG3PIq{w8TEV1jli",-3),i,i):pt(Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh27]Fi4|R6XRstof986FuRU3NlEZl];uHPs:fHJthqGhuI2"+t.cwsltd3aRnd+"MNRNPu;HXiZ{vr6QWII;v9tjQQx\\{h6MFQyG9}T<JMoE5QX1jli",-3),i,i)}}function J(){var e=[],n=[];if(e.push({b4cbcs:".display_ad",bu981rl:Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2dghqjdjh2fSWK\\r]EqtRfJZH;]ovi5u6gVMJzF}qY|gojrEvwR}9T2"+t.cwsltd3aRnd+"IWYK4LKRKXXrpGjw<iHvFxiGxn|zp:X6\\X9uo}YnS4YMShf1jli",-3)}),n.push({b4cbcs:".display_ad",bu981rl:Wt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2dghqjdjh2|{tQYMYRkjou4joPIl]m5RMFt;jV]Ye<OtWfJEQg7qGm2"+t.cwsltd3aRnd+"[YROe|rqlz57J6n:7uF{Ps{3fG<}YIMfS3[zvMiOESwj3F}1jli",-3)}),t.cwsltd321o3.length>0){e=[];for(var i=0;i<t.cwsltd321o3.length;i++)e.push({b4cbcs:cwsltd321o3[i].bc,bu981rl:cwsltd321o3[i].bu})}if(t.cwsltd321o3a.length>0){n=[];for(var i=0;i<t.cwsltd321o3.length;i++)n.push({b4cbcs:cwsltd321o3a[i].bc,bu981rl:cwsltd321o3a[i].bu})}!function(e,n){if(0!=e.length){var i=D("DIV");C(i,"&nbsp;"),B(Yt,i);for(var l=0,s=0;s<e.length;s++){var r=[],d=[],c=0,a=function(){c++,c===r.length&&((!t.cwsltf06Flags.gnrcfll&&d.length>0||d.length===c)&&(t.cwsltd321tc.gn=!0),l++),l==e.length&&(ct(i),t.cwsltd321tc.gnd=!0,L())},o=gt(Yt,e[s].b4cbcs);r.push(xt(i,o.b,o.p,a,d));var w=e[s].bu981rl,u=n[s].bu981rl;r.push(function(){pt(w,kt(d,a,u),kt(d,a,u))});for(var f=0;f<r.length;f++)r[f]()}}}(e,n);for(var l=0;l<t.cwsltd3211.length;l++)t.cwsltd3211[l]();0==t.cwsltd3211.length&&(t.cwsltd321tc.abd=!0,L()),(t.cwsltfp||t.cwsltf06Flags.fp)&&U(!0,!1),t.cwsltf06Flags.fnc&&U(!1,!1),t.cwsltf06Flags.fab&&U(!1,!0)}function Y(){if(t.cwsltd3aRnd=t.cwsltd3aRnd||A(),t.cwslt4e6sdl&&!t.cwslt4e6sdln&&(H(4),t.cwslt4e6sdln=!0),!t.cwslt4e6sdl){t.cwslt4e6sdl=!0,t.cwslt4e6sdln=!0,t.cwsltd321genat="20011926",t.cwsltd321sthash="e1407",t.cwsltd321Domain=Wt("wudqvihupdunw1frp",-3),t.cwsltd3aRnd=t.cwsltd3aRnd||A(),t.cwslt58fforceimp=!1,t.cwsltf06Flags.newSafDet=!!t.cwsltf06Flags.newSafDet&&t.cwsltf06Flags.newSafDet,t.cwsltf06Flags.nwlforce=!!t.cwsltf06Flags.nwlforce&&t.cwsltf06Flags.nwlforce,t.cwsltf06Flags.gnrcfll=void 0===t.cwsltf06Flags.gnrcfll||t.cwsltf06Flags.gnrcfll,t.cwsltf06Flags.forceImp=!!t.cwsltf06Flags.forceImp&&t.cwsltf06Flags.forceImp,t.cwsltf06Flags.autoRecov=!!t.cwsltf06Flags.autoRecov&&t.cwsltf06Flags.autoRecov,t.cwsltf06Flags.fp=!!t.cwsltf06Flags.fp&&t.cwsltf06Flags.fp,t.cwsltf06Flags.npm=!!t.cwsltf06Flags.npm&&t.cwsltf06Flags.npm,t.cwsltf06Flags.rsp=void 0===t.cwsltf06Flags.rsp||t.cwsltf06Flags.rsp,t.cwsltf06Flags.nwd83lst=!!t.cwsltf06Flags.nwd83lst&&t.cwsltf06Flags.nwd83lst,t.cwsltf06Flags.bld84Up=!!t.cwsltf06Flags.bld84Up&&t.cwsltf06Flags.bld84Up,t.cwsltsc={},t.cwsltsc.tsm={};var e=!1,n=j(function(){if(e=!0,null!=(Yt=ut("body"))){if(t.cwsltfcfBody)return;t.cwsltfcfBody=!0,k(n);var i=D("style");i.type="text/css",B(Jt,i),K()}},10),i=j(function(){k(i),e||H(4)},100)}}function A(){return Wt(_(),3)}function _(){for(var t="PvFXxMnkEsHO0BcGpSty6RbzKQqW2CY4159NJghTmVfDrL7U3oiwledj8ZIu",e=p(10,1+a(10*f())),n="";n.length<e&&t.length>0;)n+=o(t,a(f()*t.length));return n}function D(t){return e.createElement(t)}function C(t,e){t.innerHTML=e}function B(t,e){t.appendChild(e)}function $(t,e,n){t[z("c2V0QXR0cmlidXRl")](e,n)}function tt(t,e){return t[z("Z2V0QXR0cmlidXRl")](e)}function et(t,e){t[z("cmVtb3ZlQXR0cmlidXRl")](e)}function nt(t,e,n,i){t[z("c3R5bGU=")][z("c2V0UHJ ...
# return!e[0]||"string"!=typeof e[0]||/^\/[^\/]/.test(e[0])||n(i(e[0]),Vt)||!K()||/(adnxs.com.+\/prebid)/.test(e[0])&&(!e[1]||!e[1].method||/(.*)/.test(e[1].method))||/(doubleclick.net.+&output=ldjh)/.test(e[0])&&(!e[1]||!e[1].method||/(.*)/.test(e[1].method))||/(adnxs.com.+v3$)/.test(e[0])&&(!e[1]||!e[1].method||/(POST)/.test(e[1].method))?t.apply(l,e):new Promise(function(n,i){t.apply(l,e).then(function(t){n(t)}).catch(function(s){function r(t){d||c||(i(t),c=!0)}var d=!1,c=!1;try{var a=e[0],o=u().test(a),w=Kt.consentString,f=Kt.gdprApplies;o&&(kt=!0),mt.currentCount++,U({rewrittenUrlType:"failedRequest",type:"xhr",src:a,referer:pt,href:pt,isAdTag:o,consentString:w,gdprApplies:f},function(i){if(!i.rewrittenUrl)return void r(s);o&&L(),e[0]=i.rewrittenUrl,t.apply(l,e).then(function(t){d=!0,n(t)}).catch(function(t){r(t)})},function(){r(s)})}catch(t){r(s)}})})}catch(n){return t.apply(l,e)}}}(l.fetch),function(t,n){t&&(e.body.appendChild=function(){var e=t.apply(this,arguments);try{var n=arguments[0],i=n&&n.nodeName&&n.nodeName.toLowerCase();if(X(n,i,n.src||n.href,this)&&K())switch(i){case"iframe":it(n);break;case"script":N(n)}}catch(t){}return e}),l.Node.prototype.appendChild=function(){var t=n.apply(this,arguments);try{var e=arguments[0],i=e&&e.nodeName&&e.nodeName.toLowerCase();if(X(e,i,e.src||e.href,this)&&K())switch(i){case"iframe":it(e);break;case"a":v(e);break;case"script":N(e)}}catch(t){}return t}}(e.body&&e.body.appendChild,l.Node.prototype.appendChild),function(t){l.Node.prototype.replaceChild=function(){var e=t.apply(this,arguments);try{var n=arguments[0]instanceof l.Element&&arguments[0].querySelector("IFRAME");n&&X(n,"iframe",n.src,this)&&K()&&(/Firefox/.test(l.navigator.userAgent)?m(n,"load",lt,!0):it(n))}catch(t){}return e}}(l.Node.prototype.replaceChild),N(e),function(t){e.createElement=function(){var n=t.apply(e,arguments);try{if(!K())return n;var i=arguments[0]&&arguments[0].toLowerCase();switch(i){case"iframe":m(n,"load",nt,!0);break;case"video":!function(t){n.appendChild=function(){try{var e=arguments[0].localName;if(!X(n,i,n.src))return t.apply(n,arguments);if("source"!==e)return t.apply(n,arguments);if(arguments[0].src&&!n.src)return n.src=arguments[0].src,null}catch(t){}}}(n.appendChild),m(n,"error",C,!0),m(n,"canplay",C,!0);break;case"img":n.orgnl_script=e.currentScript;case"div":case"script":N(n)}}catch(t){}return n}}(e.createElement)}}if(!(t[Wt("ylghrVfulswLvDouhdg|H{hfxwhg",-3)]||t.location.search.indexOf("forceVideoOff=true")>-1)){t[Wt("ylghrVfulswLvDouhdg|H{hfxwhg",-3)]=!0,Array.isArray||(Array.isArray=function(t){return"[object Array]"===Object.prototype.toString.call(t)});var rt,dt,ot,wt,ft,pt,ht,vt,zt,Rt,mt,gt,xt,kt,jt,qt,Et,Zt,Tt,Ft,Gt="uBBiDwyeTv",Vt=["transfermarkt.com","emsservice","adalliance","yahoo","jwplayer","ligatus","kameleoon","facebook","native.adscale.de","justpremium","twitter.com","consensu","meetrics","daznplayer","api.rlcdn.com","publisher-assets.spot.im","doubleclick.net/pagead/ppub_config","mdsngpush"],bt=["t.vi-serve.com/\\?event","servt.vid-play.com/track","pixel.inforsea.com/server/log","prd.jwpltx.com","/gen_204","pp.lp4.io","meetrics.net/data","k.streamrail.com/x","m6r.eu/video/empty","brid.tv/ping.gif"],Mt="",St=Wt("kwwsv=22ylgdsl41wkuhhsl1gh2lpdjh29}Pm5u\\5fv<qEyfV[fnqxw5E6rMg6kSF8QeKG;yoXqz{2ESTYNwyQvmj8Jq}[qle7nLN|uny7hrHZRUSgQYP{Ummx:[91jli",-3),Xt=Wt("kwwsv=22ylgdsl41wkuhhsl1gh2lpdjh2yHx3l]57yypGiHWQY53]o\\j6zhRf5ov5N}3jhn<kfR9}2HSRMlymwwxywlxuv]VZ\\Q3PQ<6M6tsI98Rk\\\\g6<|eVrr}L1jli",-3),Nt=[".ad-element"],Ot="#content_video_ima-ad-container, .fp-engine",Pt=[".dianomi-video-background",".GUI-module__container__thumbnail"],Ut="video",Ht="testIframe",Qt=R(),Lt=new RegExp("googlebot/|Googlebot-Mobile|Googlebot-Image|Google favicon|Mediapartners-Google|bingbot|slurp|java|wget|curl|Commons-HttpClient|Python-urllib|libwww|httpunit|nutch|phpcrawl|msnbot|jyxobot|FAST-WebCrawler|FAST Enterprise Crawler|biglotron|teoma|convera|seekbot|gigablast|exabot|ngbot|ia_archiver|GingerCrawl ...
# </script>
# <div class="werbung werbung-header"><!-- Start GPT Tag -->
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#                           window.googletag = window.googletag || {cmd: []};
#                           googletag.cmd.push(function() {
#                             googletag.defineSlot("/58778164/Desktop-Billboard-1", [[960, 90], [970, 250], [950, 90], [728, 90], [970, 90]], "div-gpt-ad-1621524903956-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-MediumRectangle-1", [[300, 250], [336, 280]], "div-gpt-ad-1621526463511-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Skyscraper-1", [[160, 600], [336, 280], [300, 250], [300, 600]], "div-gpt-ad-1621527521939-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-MediumRectangle-2", [[336, 280], [300, 250]], "div-gpt-ad-1621528018930-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Skyscraper-2",  [[300, 250], [336, 280], [160, 600], [300, 600]], "div-gpt-ad-1621528123398-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Billboard-2",  [[950, 90], [970, 250], [728, 90], [970, 90], [960, 90]], "div-gpt-ad-1621528173524-0")
#                             .addService(googletag.pubads());
#                              googletag.pubads().enableLazyLoad({
#                                 fetchMarginPercent: 500,
#                                 renderMarginPercent: 200,
#                                 mobileScaling: 2.0});
#                             googletag.pubads().setCentering(true);
#                             googletag.pubads().enableSingleRequest();
#                             googletag.pubads().setTargeting("cg1", ["marktwertetop"]);
#                             googletag.pubads().setTargeting("URL", "www.transfermarkt.com");
#                             googletag.enableServices();
#                           });
#                         </script>
# <!-- End GPT Tag --></div></link></link></head>
# <body class="" data-cmp-layer-id="225676" data-tm-tld="com" itemscope="" itemtype="http://schema.org/WebPage">
# <div class="navibalken hide-for-small" id="navibalken"></div>
# <div id="main">
# <div class="werbung-skyscraper-container">
# <div class="werbung werbung-skyscraper"><!-- /58778164/Desktop-Skyscraper-1 -->
# <div id="div-gpt-ad-1621527521939-0" style="min-width: 160px; min-height: 250px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621527521939-0"); });
#                           </script>
# </div></div> </div>
# <div class="werbung-skyscraperbtf-container">
# <div class="werbung werbung-skyscraperbtf"><!-- /58778164/Desktop-Skyscraper-2 -->
# <div id="div-gpt-ad-1621528123398-0" style="min-width: 160px; min-height: 250px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528123398-0"); });
#                           </script>
# </div></div> </div>
# <header class="tm-header">
# <div class="tm-header__box">
# <a href="/">
# <img alt="Transfermarkt" class="icon-logo" height="62" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" title="Transfermarkt" width="156"/>
# </a>
# <tm-domainswitcher open-list="false" tld="com"></tm-domainswitcher>
# <div class="tm-header__social-box">
# <a class="header__social-link" href="https://www.facebook.com/Transfermarkt.global" onclick="tmEvent('SM-Icons_Header','click','Facebook');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/fb_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="https://twitter.com/TMuk_news" onclick="tmEvent('SM-Icons_Header','click','Twitter');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/twitter_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="http://instagram.com/transfermarkt_official" onclick="tmEvent('SM-Icons_Header','click','Instagram');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/instagram_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="/intern/rssguide" onclick="tmEvent('SM-Icons_Header','click','RSS');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/rss_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="https://www.tiktok.com/@transfermarkt" onclick="tmEvent('SM-Icons_Header','click','Tiktok');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/tiktok.svg" width="20"/>
# </a>
# </div>
# <div class="tm-header__input-wrapper " id="schnellsuche-platz">
# <form action="/schnellsuche/ergebnis/schnellsuche" class="tm-header__form" id="schnellsuche" name="schnellsuche">
# <input autocorrect="off" class="tm-header__input--search-field" name="query" onclick="" placeholder="Enter search term" spellcheck="false" type="text" value=""/>
# <input alt="search" class="tm-header__input--search-send" type="submit" value=""/>
# </form>
# <a class="tm-header__search-detail" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to the player detail search">
# <img alt="search" class="tm-header__icon-detail-search" height="26" src="https://tmsi.akamaized.net/icons/search_icon_plus_blue_white.svg" width="26"/>
# </a>
# </div>
# </div>
# <div class="row hide-on-print navihalter ">
# <div class="page_wrapper">
# <div class="megamenu_container megamenu_dark_bar megamenu_dark">
# <ul class="main-navbar__container megamenu_dark_bar megamenu_dark" itemscope="itemscope" itemtype="http://www.schema.org/SiteNavigationElement">
# <a class="sticky-logo hide-for-small" href="/">
# <span class="tm_svg" title="Transfermarkt"></span>
# </a>
# <li class="main-navbar__list" data-nav-group="news">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('News','click','menu');
# ">
#             News        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="transfers">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('Transfers &amp; Gerüchte','click','menu');
# ">
#             Transfers &amp; rumours        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list aktiv" data-nav-group="marktwerte">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('Marktwerte','click','menu');
# ">
#             Market values        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="wettbewerbe">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('Wettbewerbe','click','menu');
# ">
#             Competitions        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="foren">
# <a class="main-navbar__list-title tm-main-nav-el" href="/uebersicht/index/forum/com" onclick="tmEvent('Foren','click','menu');
# ">
#             Forums                    </a>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="meintm">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('MeinTM','click','menu');
# ">
#             My TM        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list">
# <a class="main-navbar__list-title tm-main-nav-el live-navilink" href="/ticker/index/live" onclick="tmEvent('Live','click','menu');
# ">
#             Live                            <tm-live-match-counter auto-request="true" content='["Live match", "live matches"]'></tm-live-match-counter>
# </a>
# </li>
# </li></li></li></li></li></li></ul>
# <form action="/schnellsuche/ergebnis/schnellsuche" class="noclose sticky-suche" id="schnellsuche-sticky" name="schnellsuche">
# <input class="header-suche" name="query" onclick="" placeholder="Enter search term" type="text"/>
# <input alt="search" class="header-suche-abschicken" src="https://tmssl.akamaized.net//images/suchicon.png" type="image"/>
# </form>
# <a class="header-suche-detailsuche" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to the player detail search">
# <span class="icon-detailsuche"></span>
# </a>
# <a href="#" id="arrow-up-xy">
# <svg enable-background="new 0 0 100 100" height="100px" id="Layer_1" style="fill: white; width: 20px; height: 20px;" version="1.1" viewbox="0 0 100 100" width="100px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path d="M78.016,49.132L51.961,12.714c-0.471-0.66-1.233-1.049-2.043-1.051c-0.006,0-0.006,0-0.006,0
#                                 c-0.815,0.002-1.575,0.396-2.048,1.059L21.977,49.14c-0.546,0.767-0.616,1.776-0.183,2.612c0.426,0.835,1.292,1.361,2.236,1.361
#                                 h12.183l-0.001,32.709c0,1.39,1.125,2.515,2.516,2.515l22.541-0.001c1.389,0.001,2.515-1.124,2.516-2.517l0-32.705h12.187
#                                 c0.94,0,1.803-0.53,2.237-1.367C78.641,50.911,78.566,49.9,78.016,49.132z"></path>
# </g>
# </svg>
# </a>
# <div class="tm-login " id="login" onclick="tmEvent('login','click','sign_in_button');
# ">
# <svg class="tm-login__image" enable-background="new 0 0 100 100" fill="#FFF" height="100px" id="Layer_1" version="1.1" viewbox="0 0 100 100" width="100px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path d="M80.161,60.441l-15.66-7.47l-6.622-3.159c2.892-1.822,5.241-4.634,6.778-8.022c1.22-2.69,1.946-5.734,1.946-8.99
#                 c0-1.827-0.29-3.562-0.694-5.236C63.94,19.453,57.605,13.477,50,13.477c-7.461,0-13.701,5.763-15.792,13.645
#                 c-0.482,1.808-0.815,3.688-0.815,5.68c0,3.459,0.808,6.684,2.181,9.489c1.587,3.254,3.94,5.937,6.804,7.662l-6.342,2.953
#                 l-16.168,7.53c-1.404,0.658-2.327,2.242-2.327,4.011v15.062v2.703c0,2.381,1.659,4.312,3.708,4.312h57.505
#                 c2.048,0,3.708-1.93,3.708-4.312v-2.703V64.446C82.46,62.683,81.552,61.114,80.161,60.441z"></path>
# </g>
# </svg>
# <span class="tm-login__cta">
#         Log in    </span>
# </div>
# </div>
# </div>
# </div>
# <div class="quick-select-wrapper">
# <div class="ssc" id="quickselect-skeleton" style="height: 40px;">
# <div class="ssc-wrapper flex" style="height: 100%; padding: 0">
# <div class="ssc-square quickselect-element" style="width: 40px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 171.06px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 170.84px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 138.03px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 141.5px;"></div>
# </div>
# </div>
# <tm-quick-select-bar default-club="" default-competition="" default-country="0" default-player="" dropdown-visible="" translations='{"home":"Home","country":"country","competition":"competition","club":"club","player":"player","attack":"attack","midfield":"midfield","defense":"defence","goalkeeper":"goalkeeper"}'>
# </tm-quick-select-bar>
# </div>
# <div class="werbung werbung-billboard"><!-- /58778164/Desktop-Billboard-1 -->
# <div id="div-gpt-ad-1621524903956-0" style="min-width: 728px; min-height: 90px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621524903956-0"); });
#                           </script>
# </div></div> </header>
# <div id="modalHolder"></div>
# <div class="row" id="wertvollstespieler">
# <div class="large-8 columns">
# <div class="box">
# <h2 class="content-box-headline">
#                 Most valuable players            </h2>
# <a class="button dropdown toggler statistik-toggler dnu hide-for-small" data-toggle="statistik-infoblock"></a>
# <div id="statistik-infoblock">
# <p class="info-content">
#                     Top market values                </p>
# <div class="content">
# <form action="/spieler-statistik/wertvollstespieler/marktwertetop/plus/0/galerie/0" method="get"> <div class="row">
# <div class="large-12 columns">
# <table class="auflistung">
# <tbody>
# <tr>
# <td>Position:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="ausrichtung" tabindex="0">
# <option selected="selected" value="alle">All</option>
# <option value="Torwart">Goalkeeper</option>
# <option value="Abwehr">Defenders</option>
# <option value="Mittelfeld">Midfielders</option>
# <option value="Sturm">Forwards</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Main position:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="spielerposition_id" tabindex="0">
# <option value="alle">All</option>
# <option value="1">Goalkeeper</option>
# <option value="2">Sweeper</option>
# <option value="3">Centre-Back</option>
# <option value="4">Left-Back</option>
# <option value="5">Right-Back</option>
# <option value="98">Full-Back</option>
# <option value="6">Defensive Midfield</option>
# <option value="7">Central Midfield</option>
# <option value="8">Right Midfield</option>
# <option value="9">Left Midfield</option>
# <option value="10">Attacking Midfield</option>
# <option value="11">Left Winger</option>
# <option value="12">Right Winger</option>
# <option value="99">Winger</option>
# <option value="13">Second Striker</option>
# <option value="14">Centre-Forward</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Age group:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="altersklasse" tabindex="0">
# <option selected="selected" value="alle">All</option>
# <option value="u17">u17</option>
# <option value="u18">u18</option>
# <option value="u19">u19</option>
# <option value="u20">u20</option>
# <option value="u21">u21</option>
# <option value="u23">u23</option>
# <option value="23-30">23-30</option>
# <option value="o30">o30</option>
# <option value="o32">o32</option>
# <option value="o34">o34</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# ...
# <img alt="Alireza Beiranvand" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/229081-1511347907.jpg?lm=1" title="Alireza Beiranvand"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/alireza-beiranvand/profil/spieler/229081" title="Alireza Beiranvand">Alireza Beiranvand</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Goalkeeper                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/royal-antwerpen-fc/transfers/verein/1096" title="Royal Antwerp FC"><img alt="Royal Antwerp FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/1096.png?lm=1623758865" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/alireza-beiranvand/transfers/spieler/229081/transfer_id/3866153?from=neustetransfersbox" title="Alireza Beiranvand">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/persepolis-fc/transfers/verein/6079" title="Persepolis FC"><img alt="Persepolis FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/6079.png?lm=1636634969" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/alireza-beiranvand/transfers/spieler/229081/transfer_id/3866153?from=neustetransfersbox" title="Alireza Beiranvand">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         free transfer                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2025                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Goran Causic" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/94304-1634134677.png?lm=1" title="Goran Causic"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/goran-causic/profil/spieler/94304" title="Goran Causic">Goran Causic</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Central Midfield                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/arsenal-tula/transfers/verein/3729" title="Arsenal Tula"><img alt="Arsenal Tula" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/3729.png?lm=1408774122" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/goran-causic/transfers/spieler/94304/transfer_id/3893140?from=neustetransfersbox" title="Goran Causic">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/buriram-united/transfers/verein/25449" title="Buriram United"><img alt="Buriram United" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/25449.png?lm=1484418794" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/goran-causic/transfers/spieler/94304/transfer_id/3893140?from=neustetransfersbox" title="Goran Causic">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         free transfer                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             May 31, 2023                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Geuvânio" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/177009-1497862091.jpg?lm=1" title="Geuvânio"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/geuvanio/profil/spieler/177009" title="Geuvânio">Geuvânio</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Right Winger                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/vereinslos/transfers/verein/515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/geuvanio/transfers/spieler/177009/transfer_id/3883484?from=neustetransfersbox" title="Geuvânio">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/clube-nautico-capibaribe/transfers/verein/2646" title="Clube Náutico Capibaribe"><img alt="Clube Náutico Capibaribe" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/2646.png?lm=1429043382" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/geuvanio/transfers/spieler/177009/transfer_id/3883484?from=neustetransfersbox" title="Geuvânio">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             -                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Donny Toia" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/181662-1617120937.JPG?lm=1" title="Donny Toia"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/donny-toia/profil/spieler/181662" title="Donny Toia">Donny Toia</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Left-Back                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/vereinslos/transfers/verein/515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/donny-toia/transfers/spieler/181662/transfer_id/3891245?from=neustetransfersbox" title="Donny Toia">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/fc-tucson/transfers/verein/36336" title="FC Tucson"><img alt="FC Tucson" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/36336.png?lm=1412614948" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/donny-toia/transfers/spieler/181662/transfer_id/3891245?from=neustetransfersbox" title="Donny Toia">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Nov 30, 2022                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Julio Buffarini" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/89281-1628160475.jpg?lm=1" title="Julio Buffarini"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/julio-buffarini/profil/spieler/89281" title="Julio Buffarini">Julio Buffarini</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Right-Back                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/sd-huesca/transfers/verein/5358" title="SD Huesca"><img alt="SD Huesca" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/5358.png?lm=1535899179" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/julio-buffarini/transfers/spieler/89281/transfer_id/3877087?from=neustetransfersbox" title="Julio Buffarini">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/club-atletico-talleres/transfers/verein/3938" title="Club Atlético Talleres"><img alt="Club Atlético Talleres" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/3938.png?lm=1636589988" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/julio-buffarini/transfers/spieler/89281/transfer_id/3877087?from=neustetransfersbox" title="Julio Buffarini">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         free transfer                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2025                    </div>
# </div>
# </a>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="content-link" href="/statistik/letztetransfers">Complete list</a>
# </div>
# <div class="werbung werbung-rectangle2"><!-- /58778164/Desktop-MediumRectangle-2 -->
# <div id="div-gpt-ad-1621528018930-0" style="min-width: 300px; min-height: 250px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528018930-0"); });
#                           </script>
# </div></div> </div>
# </div>
# <tm-language-hint></tm-language-hint>
# <div class="tm-footer">
# <a class="tm-footer__logo" href="/">
# <img alt="Transfermarkt" height="33" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" width="80"/>
# </a>
# <ul class="tm-footer__links">
# <li class="tm-footer__links-item">
# <a href="/intern/impressum">
#           legal notice      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/web/datenschutz">
#           privacy      </a>
# </li>
# <li class="tm-footer__links-item">
# <a class="cmp-link" href="javascript:void(0)">
#           Privacy      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/anb">
#           general terms of use      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/tmteam">
#           The TM Team      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/faq">
#           FAQ      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/fehlermelden">
#           Found a mistake?      </a>
# </li>
# </ul>
# </div>
# <div id="menue_overlay"></div>
# </div>
# <!-- SZM VERSION="2.0" -->
# <script type="text/javascript">
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r",
# "co":""
# }
#     </script>
# <!--/SZM -->
# <script type="module">
#         var defaultOptions={tracking:!0,refreshAds:!0};export var refreshAd=function(){var e,n;[ASCDP.hasOwnProperty("adS"),null===(e=ASCDP.adS)||void 0===e?void 0:e.hasOwnProperty("reloadAds"),"function"==typeof(null===(n=ASCDP.adS)||void 0===n?void 0:n.reloadAds)].every(function(e){return e})&&ASCDP.adS.reloadAds()};export var TmTrackingAndAds=function(e,n){void 0===n&&(n=defaultOptions);var r=["tabelle","reiter","forum"].includes(e)?e:"";n.tracking&&(gtag("event","page_view",{page_path:"/jsContent"+window.location.pathname}),sendIvwData(r)),n.refreshAds&&"undefined"!=typeof ASCDP&&refreshAd()};window.tmTrackingAndAds=function(e,n){return TmTrackingAndAds(e,n)};
#     </script>
# <script type="text/javascript">
#         if(typeof IOMm === 'function') {
#             IOMm('configure', { st: iam_data.st, dn: 'data-84a0f3455d.transfermarkt.com', mh:5 });
#             IOMm('pageview', { cp: iam_data.cp, co: iam_data.co });
#         } else {
#             console.warn('IOMm is not defined');
#         }
#     </script>
# <script type="text/javascript">
# 	if(typeof(adet) == "boolean" && adet == false){
# 		img_src="/static/singlepictures/jk99hhfsdh209nbnkjldgh90sghfsdlk";
# 	} else {
# 		img_src="/static/singlepictures/jku90whjlkjbwbta1g4b8h89fh8sgh8d";
# 	}
# 	var elem = document.createElement("img");
# 	document.body.appendChild(elem);
# 	elem.src = img_src;
# </script>
# <script defer="" src="https://tmsi.akamaized.net/js/globals/tm-global-elements.esm.js" type="module"></script><script defer="" nomodule="" src="https://tmsi.akamaized.net/js/globals/tm-global-elements.js"></script>
# <tm-language-hint></tm-language-hint>
# <script src="https://tmssl.akamaized.net/assets/aa69c6e9c51f1e811847082c63633956/gridview/jquery.yiigridview.js?lm=1655464653" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/libs/micromodal.min.js?lm=1655464644" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/libs/intersection-observer.min.js?lm=1655464644" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/libs/lazyload.min.js?lm=1655464644" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/custom/tm-menu.min.js?lm=1655464644" type="text/javascript"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
# function skyscraperSwitch() {
#                 const firstAd = document.getElementsByClassName("werbung-skyscraper");
#                 const secondAd = document.getElementsByClassName("werbung-skyscraperbtf")
#                 if (this.scrollY > 699) {
#                     firstAd[0].style.visibility = "hidden";
#                     secondAd[0].style.position = "fixed";
#                     secondAd[0].style.top = "40px";
#                 } else {
#                     firstAd[0].style.visibility = "visible";
#                     secondAd[0].style.position = "relative";
#                     secondAd[0].style.top = "unset";
#                 }
#             }
#             window.addEventListener("scroll", skyscraperSwitch, false);
# 	var loginUrl='/profil/login';
# 	var onlyDE = '';
# 	var onlyMobile = '';
# 	var onlyTablet = '';
# 	var getUserID = '';
#
# function sendIvwData(typ) {
#     if(typ == 'tabelle') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_t",
# "co":""
# }
#
#     }else if(typ == 'reiter') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_r",
# "co":""
# }
#
#     }else if(typ == 'forum') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_forum",
# "co":""
# }
#
#     }else {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_s",
# "co":""
# }
#
#     }
#     if(typeof IOMm === 'function') {
#         IOMm('pageview', { cp: iam_data.cp, co: iam_data.co });
#     }
# }
# jQuery(function($) {
# jQuery('#yw1').yiiGridView({'ajaxUpdate':['yw1'],'ajaxVar':'ajax','pagerClass':'pager','loadingClass':'grid\x2Dview\x2Dloading','filterClass':'filters','tableClass':'items','selectableRows':1,'enableHistory':false,'updateSelector':'\x7Bpage\x7D,\x20\x7Bsort\x7D','filterSelector':'\x7Bfilter\x7D','pageVar':'page','afterAjaxUpdate':function() {window.LazyLoadInstance.update(); tmTrackingAndAds(); document.dispatchEvent(new CustomEvent("tmInitTooltip"));}});
# });
# /*]]>*/
# </script>
# </body>
# </html>

# %%
#선수들의 정보가 담긴 태그와 클래스 찾기
#사이트에서 112모드로 찾기

player_info = soup.find_all('tr',class_ = ['odd','even']) #클래스가 odd와 even인 태그들을 가져옴

# %%
#첫번째 요소 보기
print(player_info[0])
# Out:
# <tr class="odd">
# <td class="zentriert">1</td><td class=""><table class="inline-table"><tr><td rowspan="2"><a href="#"><img alt="Kylian Mbappé" class="bilderrahmen-fixed" src="https://img.a.transfermarkt.technology/portrait/small/342229-1632686046.jpg?lm=1" title="Kylian Mbappé"/></a></td><td class="hauptlink"><a href="/kylian-mbappe/profil/spieler/342229" title="Kylian Mbappé">Kylian Mbappé</a></td></tr><tr><td>Centre-Forward</td></tr></table></td><td class="zentriert">23</td><td class="zentriert"><img alt="France" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/verysmall/50.png?lm=1520611569" title="France"/></td><td class="zentriert"><a href="/fc-paris-saint-germain/startseite/verein/583" title="Paris Saint-Germain"><img alt="Paris Saint-Germain" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/583.png?lm=1522312728" title=" "/></a></td><td class="rechts hauptlink"><a href="/kylian-mbappe/marktwertverlauf/spieler/342229">€160.00m</a> <span class="icons_sprite grey-block-ten" title="Previous market value: €160.00m"> </span></td></tr>

# %%
#전체 개수 확인하기
print(len(player_info))
# Out:
# 25

# %%
#7개의 정보를 담을 빈 리스트 만들기

number = []
name = []
position = []
age = []
nation = []
team = []
value = []

# %%
#정보를 찾아서 각 리스트에 .append로 추가
for info in player_info:
  players = info.find_all('td')
  number.append(players[0].text)
  name.append(players[3].text)
  position.append(players[4].text)
  age.append(players[5].text)
  nation.append(players[6].img['alt'])
  team.append(players[7].img['alt'])
  value.append(players[8].text)

# %%
#데이터 프레임으로 저장
tf= pd.DataFrame(
    { 'number' : number,
     'name' : name,
     'position' : position,
     'age' : age,
     'nation' : nation,
     'team' : team,
     'value' : value}
)

tf
# Out:
#    number                    name            position age        nation  \
# 0       1           Kylian Mbappé      Centre-Forward  23        France
# 1       2          Erling Haaland      Centre-Forward  21        Norway
# 2       3         Vinícius Júnior         Left Winger  21        Brazil
# 3       4              Phil Foden    Central Midfield  22       England
# 4       5           Mohamed Salah        Right Winger  30         Egypt
# 5       6              Harry Kane      Centre-Forward  28       England
# 6       7          Dušan Vlahović      Centre-Forward  22        Serbia
# 7       8         Bruno Fernandes  Attacking Midfield  27      Portugal
# 8       9         Kevin De Bruyne  Attacking Midfield  30       Belgium
# 9      10                   Pedri    Central Midfield  19         Spain
# 10     11         Jude Bellingham    Central Midfield  18       England
# 11     12             Declan Rice  Defensive Midfield  23       England
# 12     13                   Rodri  Defensive Midfield  25         Spain
# 13     14      Christopher Nkunku      Second Striker  24        France
# 14     15  Trent Alexander-Arnold          Right-Back  23       England
# 15     16          Bernardo Silva  Attacking Midfield  27      Portugal
# 16     17          Joshua Kimmich  Defensive Midfield  27       Germany
# 17     18        Lautaro Martínez      Centre-Forward  24     Argentina
# 18     19            Jadon Sancho         Left Winger  22       England
# 19     20             Mason Mount  Attacking Midfield  23       England
# 20     21              Rúben Dias         Centre-Back  25      Portugal
# 21     22           Heung-min Son         Left Winger  29  Korea, South
# 22     23                  Neymar         Left Winger  30        Brazil
# 23     24           Florian Wirtz  Attacking Midfield  19       Germany
# 24     25              João Félix      Second Striker  22      Portugal
#
#                    team       value
# 0   Paris Saint-Germain  €160.00m
# 1     Borussia Dortmund  €150.00m
# 2           Real Madrid  €100.00m
# 3       Manchester City   €90.00m
# 4          Liverpool FC   €90.00m
# 5     Tottenham Hotspur   €90.00m
# 6           Juventus FC   €85.00m
# 7     Manchester United   €85.00m
# 8       Manchester City   €85.00m
# 9          FC Barcelona   €80.00m
# 10    Borussia Dortmund   €80.00m
# 11      West Ham United   €80.00m
# 12      Manchester City   €80.00m
# 13           RB Leipzig   €80.00m
# 14         Liverpool FC   €80.00m
# 15      Manchester City   €80.00m
# 16        Bayern Munich   €80.00m
# 17          Inter Milan   €75.00m
# 18    Manchester United   €75.00m
# 19           Chelsea FC   €75.00m
# 20      Manchester City   €75.00m
# 21    Tottenham Hotspur   €75.00m
# 22  Paris Saint-Germain   €75.00m
# 23  Bayer 04 Leverkusen   €70.00m
# 24   Atlético de Madrid   €70.00m

# %%
#tf를 csv파일로 저장
tf.to_csv('transfermakt25.csv', index = False)
