# %%
# /content/drive 경로로 colab에서 드라이브 접근 가능하도록 하기
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# pandas, numpy, seaborn, matplotlib.pyplot 라이브러리 가져오기
# pd, np, sns, plt로 별칭 설정해서 가져오기
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# font=nanum 사용할 수 있게 설치하기
# !apt-get install fonts-nanum* -qq
# font_manager 라이브러리 가져오기, 별칭(fm) / font_manager 는 matplotlib.
import matplotlib.font_manager as fm
# 내가 사용할 수 있는 글꼴 확인하기 - 변수 : all_fonts_i_cna_use 에 저장
all_fonts_i_can_use = fm.findSystemFonts(fontpaths=None,fontext = 'ttf')
all_fonts_i_can_use
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155632 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# ...

# %%
# 변수 fontpath에 내가 사용할 글꼴 경로 넣기
fontpath = '/usr/share/fonts/truetype/nanum/NanumSquareR.ttf'
# 변수 font에 폰트 적용, 폰트 기본 사이즈 = 9
font = fm.FontProperties(fname = fontpath, size = 9)
# 폰트 재적용 시켜주기
fm._rebuild()
# 글꼴 선명하게 보이게 설정해주기
# %config inlineBackend.figure_format = 'retina'
# 폰트 이름 받아와서 변수 font_name에 저장하기
font_name = fm.FontProperties(fname = fontpath).get_name()
# 폰트 읽어오기
plt.rc('font',family = font_name)
# font_name 출력
font_name
# Out:
# 'NanumSquare'

# %%
# 파트 그리기 - 차트 제목 : 한글 폰트 설정
plt.title('한글제목')
# 마이너스 기호 안보일 때 설정해줘야 되는 것
plt.rc('axes',unicode_minus = )
# 차트 그리기 - 값 : -4, -6, 1, 2, 0, 3

# %%
# 판다스 csv파일 불러와서 df에 저장

# df의 데이터 개수 확인 (행, 열)

# %%
# 위에서 부터 10개 데이터 출력

# %%
# 끝에서 부터 10개 데이터 출력

# %%
# df 인덱스 확인

# %%
# df 열 이름 확인

# %%
# df 정보 확인

# %%
# df 열 데이터 타입 확인

# %%
# 변수 df에 저장된 null값의 합계를 변수 n에 저장하고 출력하기

# %%
# 변수 n을 값으로 정렬하여 bar파트 그리기, 열 이름이 세로축에 나오게 할 것
# 사이즈 = 7, 8

# %%
# 결측치 그래프를 보기 위해 라이브러리 불러옴, 별칭 msno로 실행
# matrix 형태의 그래프 출력

# heatmap 형태의 그래프 출력

# dendrogram 그래프 출력

# %%
# not_use 변수에 결측치 값(큰 -> 작은) 순서로 정렬하여 상위 9개만 저장하기

# not_use의 인덱스를 not_use_col 변수에 저장하고 출력

# %%
# 변수 df의 형태 출력

# not_use_col에 저장된 index 삭제해서 다시 df변수에 저장

# 변수 df의 형태 출력

# %%
# df 변수에 저장된 열 이름을 변수 cols에 저장하고 출력
# 열 = columns

# %%
# 변수 cols에 저장된 열 이름 중 '코드|번호'가 포함된 열을 cols_code 변수에 저장 후 출력

# %%
# 변수 df의 형태 출력

# cols_code에 저장된 index 삭제해서 다시 df 변수에 저장

# 변수 df의 형태 출력

# %%
# 변수 df에 '상권업종대분류명'의 유일값 출력(중복 X)

# %%
# 상권업종대분류명이 학문/교육인 데이터만 데이터프레임 형태로 가져오기

# %%
# 시도명이 서울특별시인 데이터 출력

# %%
# 시도명이 서울특별시이고 상권업종대분류명이 학문/교육인 데이터를 가지고 와서 df_academy에 복사하여 저장하고 출력

# %%
# 상호명으로 빈도수 구하기

# %%
# 시군구명으로 빈도수 구하기

# %%
# 상권업종소분류명으로 빈도수를 구하고, 상위 30개 -> 정보를 academy_count라는 변수에 저장하고 출력

# %%
# academy_count에 저장된 데이터가 1000개 초과인 데이터만 출력

# academy_count 100개 초과인 데이터를 academy_count_1000 변수에 저장하고 출력

# %%
# df_academy의 상권업종소분류명의 유일값 출력

# %%
# 시군구명, 상권업종소분류명이 멀티 인덱스가 되게 하고, 상호명을 기준으로 개수 세어서 academy_group 변수에 저장, 출력

# %%
# 강남구에 있는 검도도장 조회하기

# %%
# academy_group이 멀티인덱스로 되어있기 때문에 인덱스 초기화 시켜주기
# 변수 t에 초기화한 정보 출력

# %%
# 상호명을 상호수로 칼럼 이름 바꿔주기

# %%
# 위에서 구한 결과를 시군구명, 상호수로 barplot 그리기
# 95% 샘플링 값 안보이게 옵션 설정하기

# %%
# academy_count_1000에 저장된 인덱스 출력하기

# %%
# df_academy에 저장된 형태 출력하기

# df_academy에 저장된 데이터 중 상권업종소분류명으로 분류한 갯수가 1000개 이상인 데이터와 일치하는 정보를 가져와서
# df_academy_selected에 복사하여 저장

# df_academy_selected 형태 출력하기

# %%
# 법정동명이 불광동인 정보를 출력

# %%
# 상권업종소분류명이 1000개 이상인 데이터만 저장되어있는 변수를 활용해서 불광동에 해당하는 상권업종소분류명의
# 상가가 몇 개 있는지 빈도수 구하기

# %%
# 변수 g에 상권업종소분류명, 시군구명 순서로 멀티인덱스 만들고 상호명을 기준으로 그룹화해서 갯수 저장하기

# %%
# 한 번에 볼 수 있는 행 1000개로 만들기

# %%
# 위에서 저장한 변수를 멀티인덱스 첫 번째 기준(오름차순), 삭ㅄ(내림차순)으로 정렬해서 출력하기

# %%
# g 사용
# 전체 구별 상권업종소분류명이 '학원-입시'인 데이터만 그래프로 그리기, 값이 내림차순으로 정렬되게 그리기
# 그래프 사이즈 : 10, 7

# %%
# 앞에서 가로 5개 세로 5개 데이터만 보고 싶을때?

# g.unstack() 그래프 그리기

# %%
# 멀티인덱스 초기화 시켜서 변수 i에 저장

# 수행평가에 반드시 나옴
# 변수명.rename(columns={'':''})

# %%
# 상권업종소분류명, 상호수로 barplot 그리기, 95% 샘플링 값 안보이게 하기
# 사이즈는 15, 4
# 사용 데이터 i

# %%
# catplot으로 그리기
# data = i, 상권업종소분류명, 상호수로 막대 그래프 그리기

# 옵션 추가 : 열이 시군구명으로 나오게 하기(범주추가) ex)종로구, 중구, 은평구 등등 시군구명으로 그래프 따로 그려지게 하기

# 옵션 추가 : 한 줄에 두 개씩 나오게 그래프 그리기
